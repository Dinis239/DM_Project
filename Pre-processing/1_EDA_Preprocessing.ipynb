# %% [markdown]
# ### EDA
#
# **Project:** Data Mining I (2025/26)
#
# **Group:** 15
#
# **Members:**
# - Beatriz Boura
# - Dinis Gaspar
# - Leonor Cardoso
# - Margarida Cruz

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# %cd ..
data = pd.read_csv('Datasets/absenteeism_data.csv', sep=';')
data
# Out:
# c:\Users\dinis\OneDrive\Ambiente de Trabalho\Faculdade - MGI-BI\1º ano\1º Semestre\Data Mining I\Project\DM_Project
# C:\Users\dinis\AppData\Roaming\Python\Python312\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
#      ID                    Reason for absence Month of absence  \
# 0    11                   Unjustified absence             July
# 1    36                           Unspecified             July
# 2     3                  Medical consultation             July
# 3     7        Diseases of the eye and adnexa             July
# 4    11                  Medical consultation             July
# ..   ..                                   ...              ...
# 795  11  Diseases of the genitourinary system             July
# 796   1      Diseases of the digestive system             July
# ...
